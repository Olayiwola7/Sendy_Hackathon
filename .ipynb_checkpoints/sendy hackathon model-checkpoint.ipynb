# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgbm
# %matplotlib inline

# %%
sendy_train = pd.read_csv('Train.csv')
sendy_test = pd.read_csv('Test.csv')

# %%
sendy_train.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)             ...              \
# 0                                5             ...
# 1                                5             ...
# 2                                2             ...
# 3                                5             ...
# 4                                1             ...
#
#   Arrival at Destination - Time  Distance (KM)  Temperature  \
# 0                   10:39:55 AM              4         20.4
# 1                   12:17:22 PM             16         26.4
# 2                    1:00:38 PM              3          NaN
# 3                   10:05:27 AM              9         19.2
# 4                   10:25:37 AM              9         15.4
#
#   Precipitation in millimeters  Pickup Lat  Pickup Long Destination Lat  \
# 0                          NaN   -1.317755    36.830370       -1.300406
# 1                          NaN   -1.351453    36.899315       -1.295004
# 2                          NaN   -1.308284    36.843419       -1.300921
# 3                          NaN   -1.281301    36.832396       -1.257147
# 4                          NaN   -1.266597    36.792118       -1.295041
#
#    Destination Long      Rider Id Time from Pickup to Arrival
# 0         36.829741  Rider_Id_432                         745
# 1         36.814358  Rider_Id_856                        1993
# 2         36.828195  Rider_Id_155                         455
# 3         36.795063  Rider_Id_855                        1341
# 4         36.809817  Rider_Id_770                        1214
#
# [5 rows x 29 columns]

# %%
sendy_train.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                      21201.000000                          21201.000000
# mean                          15.653837                              3.240225
# std                            8.798886                              1.567228
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  \
# count           21201.000000               21201.000000
# mean               15.653837                   3.240225
# std                 8.798886                   1.567228
# min                 1.000000                   1.000000
# 25%                 8.000000                   2.000000
# 50%                15.000000                   3.000000
# 75%                23.000000                   5.000000
# max                31.000000                   7.000000
#
#        Arrival at Destination - Day of Month  \
# count                           21201.000000
# mean                               15.653837
# std                                 8.798886
# min                                 1.000000
# 25%                                 8.000000
# 50%                                15.000000
# 75%                                23.000000
# max                                31.000000
#
#        Arrival at Destination - Weekday (Mo = 1)  Distance (KM)   Temperature  \
# count                               21201.000000   21201.000000  16835.000000
# mean                                    3.240225       9.506533     23.258889
# std                                     1.567228       5.668963      3.615768
# min                                     1.000000       1.000000     11.200000
# 25%                                     2.000000       5.000000     20.600000
# 50%                                     3.000000       8.000000     23.500000
# 75%                                     5.000000      13.000000     26.000000
# max                                     7.000000      49.000000     32.100000
#
#        Precipitation in millimeters    Pickup Lat   Pickup Long  \
# count                    552.000000  21201.000000  21201.000000
# mean                       7.905797     -1.281470     36.811264
# std                       17.089971      0.030507      0.037473
# min                        0.100000     -1.438302     36.653621
# 25%                        1.075000     -1.300921     36.784605
# 50%                        2.900000     -1.279395     36.807040
# 75%                        4.900000     -1.257147     36.829741
# max                       99.100000     -1.147170     36.991046
#
#        Destination Lat  Destination Long  Time from Pickup to Arrival
# count     21201.000000      21201.000000                 21201.000000
# mean         -1.282581         36.811220                  1556.920947
# std           0.034824          0.044721                   987.270788
# min          -1.430298         36.606594                     1.000000
# 25%          -1.301201         36.785661                   882.000000
# 50%          -1.284382         36.808002                  1369.000000
# 75%          -1.261177         36.829477                  2040.000000
# max          -1.030225         37.016779                  7883.000000

# %%
sendy_test.describe()
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count    7068.000000               7068.000000                   7068.000000
# mean        2.752122                 15.621817                      3.249859
# std         0.624000                  8.776650                      1.580926
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                  7068.000000                      7068.000000
# mean                     15.621817                         3.249859
# std                       8.776650                         1.580926
# min                       1.000000                         1.000000
# 25%                       8.000000                         2.000000
# 50%                      15.000000                         3.000000
# 75%                      23.000000                         5.000000
# max                      31.000000                         7.000000
#
#        Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# count                       7068.000000                           7068.000000
# mean                          15.621817                              3.249859
# std                            8.776650                              1.580926
# min                            1.000000                              1.000000
# 25%                            8.000000                              2.000000
# 50%                           15.000000                              3.000000
# 75%                           23.000000                              5.000000
# max                           31.000000                              7.000000
#
#        Pickup - Day of Month  Pickup - Weekday (Mo = 1)  Distance (KM)  \
# count            7068.000000                7068.000000    7068.000000
# mean               15.621817                   3.249859       9.458970
# std                 8.776650                   1.580926       5.575689
# min                 1.000000                   1.000000       1.000000
# 25%                 8.000000                   2.000000       5.000000
# 50%                15.000000                   3.000000       8.000000
# 75%                23.000000                   5.000000      13.000000
# max                31.000000                   7.000000      47.000000
#
#        Temperature  Precipitation in millimeters   Pickup Lat  Pickup Long  \
# count  5631.000000                    199.000000  7068.000000  7068.000000
# mean     23.246120                      6.651759    -1.282043    36.811148
# std       3.591161                     14.085439     0.030044     0.037962
# min      13.200000                      0.100000    -1.433512    36.653828
# 25%      20.600000                      1.100000    -1.301201    36.784605
# 50%      23.400000                      2.900000    -1.281301    36.807219
# 75%      25.900000                      4.950000    -1.257274    36.829716
# max      32.100000                     99.100000    -1.148352    36.991046
#
#        Destination Lat  Destination Long
# count      7068.000000       7068.000000
# mean         -1.282255         36.811326
# std           0.034236          0.043507
# min          -1.422652         36.639195
# 25%          -1.300921         36.786546
# 50%          -1.283219         36.807927
# 75%          -1.261256         36.828195
# max          -1.030225         37.018958

# %%
sendy_train['Precipitation in millimeters']= sendy_train['Precipitation in millimeters'].fillna(0)
sendy_test['Precipitation in millimeters']= sendy_test['Precipitation in millimeters'].fillna(0)

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21201 entries, 0 to 21200
# Data columns (total 29 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  16835 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# dtypes: float64(6), int64(13), object(10)
# memory usage: 4.7+ MB

# %%
sendy_train['Temperature'].mean()
# Out:
# 23.25888921888938

# %%
sendy_train['Temperature'].fillna(sendy_train['Temperature'].mean(),inplace=True)
sendy_test['Temperature'].fillna(sendy_test['Temperature'].mean(),inplace=True)

# %%
sendy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 25 columns):
# Order No                                7068 non-null object
# User Id                                 7068 non-null object
# Vehicle Type                            7068 non-null object
# Platform Type                           7068 non-null int64
# Personal or Business                    7068 non-null object
# Placement - Day of Month                7068 non-null int64
# Placement - Weekday (Mo = 1)            7068 non-null int64
# Placement - Time                        7068 non-null object
# Confirmation - Day of Month             7068 non-null int64
# Confirmation - Weekday (Mo = 1)         7068 non-null int64
# Confirmation - Time                     7068 non-null object
# Arrival at Pickup - Day of Month        7068 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)    7068 non-null int64
# Arrival at Pickup - Time                7068 non-null object
# Pickup - Day of Month                   7068 non-null int64
# Pickup - Weekday (Mo = 1)               7068 non-null int64
# Pickup - Time                           7068 non-null object
# Distance (KM)                           7068 non-null int64
# Temperature                             7068 non-null float64
# Precipitation in millimeters            7068 non-null float64
# Pickup Lat                              7068 non-null float64
# Pickup Long                             7068 non-null float64
# Destination Lat                         7068 non-null float64
# Destination Long                        7068 non-null float64
# Rider Id                                7068 non-null object
# dtypes: float64(6), int64(10), object(9)
# memory usage: 1.3+ MB

# %%
sendy_test[['Temperature']].mean()
# Out:
# Temperature    23.24612
# dtype: float64

# %%
sendy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 25 columns):
# Order No                                7068 non-null object
# User Id                                 7068 non-null object
# Vehicle Type                            7068 non-null object
# Platform Type                           7068 non-null int64
# Personal or Business                    7068 non-null object
# Placement - Day of Month                7068 non-null int64
# Placement - Weekday (Mo = 1)            7068 non-null int64
# Placement - Time                        7068 non-null object
# Confirmation - Day of Month             7068 non-null int64
# Confirmation - Weekday (Mo = 1)         7068 non-null int64
# Confirmation - Time                     7068 non-null object
# Arrival at Pickup - Day of Month        7068 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)    7068 non-null int64
# Arrival at Pickup - Time                7068 non-null object
# Pickup - Day of Month                   7068 non-null int64
# Pickup - Weekday (Mo = 1)               7068 non-null int64
# Pickup - Time                           7068 non-null object
# Distance (KM)                           7068 non-null int64
# Temperature                             7068 non-null float64
# Precipitation in millimeters            7068 non-null float64
# Pickup Lat                              7068 non-null float64
# Pickup Long                             7068 non-null float64
# Destination Lat                         7068 non-null float64
# Destination Long                        7068 non-null float64
# Rider Id                                7068 non-null object
# dtypes: float64(6), int64(10), object(9)
# memory usage: 1.3+ MB

# %%
Riders= pd.read_csv('Riders.csv')
sendy_train= pd.merge(left=sendy_train, right=Riders, how= 'left',left_on='Rider Id',right_on='Rider Id')
sendy_test= pd.merge(left=sendy_test, right=Riders, how= 'left',left_on='Rider Id',right_on='Rider Id')

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 33 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  21201 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# dtypes: float64(7), int64(16), object(10)
# memory usage: 5.5+ MB

# %%
from datetime import date
sendy_train['pickup_time']= pd.to_datetime(sendy_train['Pickup - Time'])
sendy_train['arrival_at_pickup_time']= pd.to_datetime(sendy_train['Arrival at Pickup - Time'])
sendy_train['placement_time']= pd.to_datetime(sendy_train['Placement - Time'])

sendy_test['pickup_time']= pd.to_datetime(sendy_test['Pickup - Time'])
sendy_test['arrival_at_pickup_time']= pd.to_datetime(sendy_test['Arrival at Pickup - Time'])
sendy_test['placement_time']= pd.to_datetime(sendy_test['Placement - Time'])

# %%
sendy_train['time_from_arrival_at_pickup_till_pickup'] = sendy_train['pickup_time']-sendy_train['arrival_at_pickup_time']
sendy_train['time_from_arrival_at_pickup_till_pickup'] = sendy_train['time_from_arrival_at_pickup_till_pickup']/np.timedelta64(1, 's')
sendy_train['time_from_placement_to_pickup'] = sendy_train['pickup_time']-sendy_train['placement_time']
sendy_train['time_from_placement_to_pickup']= sendy_train['time_from_placement_to_pickup']/np.timedelta64(1,'s')

sendy_test['time_from_arrival_at_pickup_till_pickup'] = sendy_test['pickup_time']-sendy_test['arrival_at_pickup_time']
sendy_test['time_from_arrival_at_pickup_till_pickup'] = sendy_test['time_from_arrival_at_pickup_till_pickup']/np.timedelta64(1, 's')
sendy_test['time_from_placement_to_pickup'] = sendy_test['pickup_time']-sendy_test['placement_time']
sendy_test['time_from_placement_to_pickup']= sendy_test['time_from_placement_to_pickup']/np.timedelta64(1,'s')

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 38 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Placement - Time                             21201 non-null object
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Arrival at Pickup - Time                     21201 non-null object
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Pickup - Time                                21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  21201 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# pickup_time                                  21201 non-null datetime64[ns]
# arrival_at_pickup_time                       21201 non-null datetime64[ns]
# placement_time                               21201 non-null datetime64[ns]
# time_from_arrival_at_pickup_till_pickup      21201 non-null float64
# time_from_placement_to_pickup                21201 non-null float64
# dtypes: datetime64[ns](3), float64(9), int64(16), object(10)
# memory usage: 6.3+ MB

# %%
sendy_train.drop(['Placement - Time','Pickup - Time', 'Arrival at Pickup - Time'], axis= 1, inplace = True)
sendy_test.drop(['Placement - Time','Pickup - Time', 'Arrival at Pickup - Time'], axis= 1, inplace = True)

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 35 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Confirmation - Time                          21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Arrival at Destination - Time                21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  21201 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# pickup_time                                  21201 non-null datetime64[ns]
# arrival_at_pickup_time                       21201 non-null datetime64[ns]
# placement_time                               21201 non-null datetime64[ns]
# time_from_arrival_at_pickup_till_pickup      21201 non-null float64
# time_from_placement_to_pickup                21201 non-null float64
# dtypes: datetime64[ns](3), float64(9), int64(16), object(7)
# memory usage: 5.8+ MB

# %%
sendy_train['confirmation_time']= pd.to_datetime(sendy_train['Confirmation - Time'])
sendy_train['arrival_at_destination_time']= pd.to_datetime(sendy_train['Arrival at Destination - Time'])

sendy_test['confirmation_time']= pd.to_datetime(sendy_test['Confirmation - Time'])
#sendy_test['arrival_at_destination_time']= pd.to_datetime(sendy_test['Arrival at Destination - Time'])

# %%
sendy_train.drop(['Confirmation - Time', 'Arrival at Destination - Time'], axis= 1, inplace = True)
sendy_test.drop(['Confirmation - Time'], axis= 1, inplace = True)

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 35 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null int64
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null int64
# Placement - Weekday (Mo = 1)                 21201 non-null int64
# Confirmation - Day of Month                  21201 non-null int64
# Confirmation - Weekday (Mo = 1)              21201 non-null int64
# Arrival at Pickup - Day of Month             21201 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null int64
# Pickup - Day of Month                        21201 non-null int64
# Pickup - Weekday (Mo = 1)                    21201 non-null int64
# Arrival at Destination - Day of Month        21201 non-null int64
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null int64
# Distance (KM)                                21201 non-null int64
# Temperature                                  21201 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# pickup_time                                  21201 non-null datetime64[ns]
# arrival_at_pickup_time                       21201 non-null datetime64[ns]
# placement_time                               21201 non-null datetime64[ns]
# time_from_arrival_at_pickup_till_pickup      21201 non-null float64
# time_from_placement_to_pickup                21201 non-null float64
# confirmation_time                            21201 non-null datetime64[ns]
# arrival_at_destination_time                  21201 non-null datetime64[ns]
# dtypes: datetime64[ns](5), float64(9), int64(16), object(5)
# memory usage: 5.8+ MB

# %%
import seaborn as sns

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')
sns.jointplot(x='Distance (KM)',y='Time from Pickup to Arrival',data=sendy_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x='time_from_placement_to_pickup',y='Time from Pickup to Arrival',data=sendy_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corrs =sendy_train.corr()

# %%
print(corrs)
# Out:
#                                            Platform Type  \
# Platform Type                                   1.000000
# Placement - Day of Month                        0.012764
# Placement - Weekday (Mo = 1)                   -0.058038
# Confirmation - Day of Month                     0.012770
# Confirmation - Weekday (Mo = 1)                -0.058005
# Arrival at Pickup - Day of Month                0.012770
# Arrival at Pickup - Weekday (Mo = 1)           -0.058005
# Pickup - Day of Month                           0.012770
# Pickup - Weekday (Mo = 1)                      -0.058005
# Arrival at Destination - Day of Month           0.012770
# Arrival at Destination - Weekday (Mo = 1)      -0.058005
# Distance (KM)                                   0.005528
# Temperature                                     0.211494
# Precipitation in millimeters                   -0.011401
# Pickup Lat                                     -0.002742
# Pickup Long                                     0.021327
# Destination Lat                                 0.006319
# Destination Long                                0.043924
# Time from Pickup to Arrival                    -0.003827
# No_Of_Orders                                    0.024060
# Age                                            -0.074029
# Average_Rating                                 -0.014664
# No_of_Ratings                                  -0.031886
# time_from_arrival_at_pickup_till_pickup         0.053344
# time_from_placement_to_pickup                   0.020411
#
#                                            Placement - Day of Month  \
# Platform Type                                              0.012764
# Placement - Day of Month                                   1.000000
# Placement - Weekday (Mo = 1)                               0.026148
# Confirmation - Day of Month                                0.999998
# Confirmation - Weekday (Mo = 1)                            0.026122
# Arrival at Pickup - Day of Month                           0.999998
# Arrival at Pickup - Weekday (Mo = 1)                       0.026122
# Pickup - Day of Month                                      0.999998
# Pickup - Weekday (Mo = 1)                                  0.026122
# Arrival at Destination - Day of Month                      0.999998
# Arrival at Destination - Weekday (Mo = 1)                  0.026122
# Distance (KM)                                             -0.007585
# Temperature                                                0.011605
# Precipitation in millimeters                              -0.044518
# Pickup Lat                                                -0.004929
# Pickup Long                                               -0.005453
# Destination Lat                                            0.007541
# Destination Long                                           0.002077
# Time from Pickup to Arrival                               -0.014710
# No_Of_Orders                                               0.008096
# Age                                                       -0.000107
# Average_Rating                                             0.012790
# No_of_Ratings                                             -0.001709
# time_from_arrival_at_pickup_till_pickup                    0.003164
# time_from_placement_to_pickup                             -0.011117
#
#                                            Placement - Weekday (Mo = 1)  \
# Platform Type                                                 -0.058038
# Placement - Day of Month                                       0.026148
# Placement - Weekday (Mo = 1)                                   1.000000
# Confirmation - Day of Month                                    0.026132
# Confirmation - Weekday (Mo = 1)                                0.999952
# Arrival at Pickup - Day of Month                               0.026132
# Arrival at Pickup - Weekday (Mo = 1)                           0.999952
# Pickup - Day of Month                                          0.026132
# Pickup - Weekday (Mo = 1)                                      0.999952
# Arrival at Destination - Day of Month                          0.026132
# Arrival at Destination - Weekday (Mo = 1)                      0.999952
# Distance (KM)                                                  0.003582
# Temperature                                                    0.027703
# Precipitation in millimeters                                  -0.024879
# Pickup Lat                                                    -0.000918
# Pickup Long                                                    0.011008
# Destination Lat                                               -0.004299
# Destination Long                                              -0.000875
# Time from Pickup to Arrival                                    0.009693
# No_Of_Orders                                                  -0.024226
# Age                                                           -0.015475
# Average_Rating                                                -0.006834
# No_of_Ratings                                                 -0.025747
# time_from_arrival_at_pickup_till_pickup                        0.014198
# time_from_placement_to_pickup                                  0.023269
#
#                                            Confirmation - Day of Month  \
# Platform Type                                                 0.012770
# Placement - Day of Month                                      0.999998
# Placement - Weekday (Mo = 1)                                  0.026132
# Confirmation - Day of Month                                   1.000000
# Confirmation - Weekday (Mo = 1)                               0.026123
# Arrival at Pickup - Day of Month                              1.000000
# Arrival at Pickup - Weekday (Mo = 1)                          0.026123
# Pickup - Day of Month                                         1.000000
# Pickup - Weekday (Mo = 1)                                     0.026123
# Arrival at Destination - Day of Month                         1.000000
# Arrival at Destination - Weekday (Mo = 1)                     0.026123
# Distance (KM)                                                -0.007587
# Temperature                                                   0.011606
# Precipitation in millimeters                                 -0.044520
# Pickup Lat                                                   -0.004923
# Pickup Long                                                  -0.005448
# Destination Lat                                               0.007550
# Destination Long                                              0.002073
# Time from Pickup to Arrival                                  -0.014701
# No_Of_Orders                                                  0.008099
# Age                                                          -0.000114
# Average_Rating                                                0.012796
# No_of_Ratings                                                -0.001712
# time_from_arrival_at_pickup_till_pickup                       0.003167
# time_from_placement_to_pickup                                -0.011105
#
#                                            Confirmation - Weekday (Mo = 1)  \
# Platform Type                                                    -0.058005
# Placement - Day of Month                                          0.026122
# Placement - Weekday (Mo = 1)                                      0.999952
# Confirmation - Day of Month                                       0.026123
# Confirmation - Weekday (Mo = 1)                                   1.000000
# Arrival at Pickup - Day of Month                                  0.026123
# Arrival at Pickup - Weekday (Mo = 1)                              1.000000
# Pickup - Day of Month                                             0.026123
# Pickup - Weekday (Mo = 1)                                         1.000000
# Arrival at Destination - Day of Month                             0.026123
# Arrival at Destination - Weekday (Mo = 1)                         1.000000
# Distance (KM)                                                     0.003574
# Temperature                                                       0.027712
# Precipitation in millimeters                                     -0.024886
# Pickup Lat                                                       -0.000883
# Pickup Long                                                       0.011036
# Destination Lat                                                  -0.004251
# Destination Long                                                 -0.000900
# Time from Pickup to Arrival                                       0.009744
# No_Of_Orders                                                     -0.024205
# Age                                                              -0.015514
# Average_Rating                                                   -0.006803
# No_of_Ratings                                                    -0.025768
# time_from_arrival_at_pickup_till_pickup                           0.014216
# time_from_placement_to_pickup                                     0.023336
#
#                                            Arrival at Pickup - Day of Month  \
# Platform Type                                                      0.012770
# Placement - Day of Month                                           0.999998
# Placement - Weekday (Mo = 1)                                       0.026132
# Confirmation - Day of Month                                        1.000000
# Confirmation - Weekday (Mo = 1)                                    0.026123
# Arrival at Pickup - Day of Month                                   1.000000
# Arrival at Pickup - Weekday (Mo = 1)                               0.026123
# Pickup - Day of Month                                              1.000000
# Pickup - Weekday (Mo = 1)                                          0.026123
# Arrival at Destination - Day of Month                              1.000000
# Arrival at Destination - Weekday (Mo = 1)                          0.026123
# Distance (KM)                                                     -0.007587
# Temperature                                                        0.011606
# Precipitation in millimeters                                      -0.044520
# Pickup Lat                                                        -0.004923
# Pickup Long                                                       -0.005448
# Destination Lat                                                    0.007550
# Destination Long                                                   0.002073
# Time from Pickup to Arrival                                       -0.014701
# No_Of_Orders                                                       0.008099
# Age                                                               -0.000114
# Average_Rating                                                     0.012796
# No_of_Ratings                                                     -0.001712
# time_from_arrival_at_pickup_till_pickup                            0.003167
# time_from_placement_to_pickup                                     -0.011105
#
#                                            Arrival at Pickup - Weekday (Mo = 1)  \
# Platform Type                                                         -0.058005
# Placement - Day of Month                                               0.026122
# Placement - Weekday (Mo = 1)                                           0.999952
# Confirmation - Day of Month                                            0.026123
# Confirmation - Weekday (Mo = 1)                                        1.000000
# Arrival at Pickup - Day of Month                                       0.026123
# Arrival at Pickup - Weekday (Mo = 1)                                   1.000000
# Pickup - Day of Month                                                  0.026123
# Pickup - Weekday (Mo = 1)                                              1.000000
# Arrival at Destination - Day of Month                                  0.026123
# Arrival at Destination - Weekday (Mo = 1)                              1.000000
# Distance (KM)                                                          0.003574
# Temperature                                                            0.027712
# Precipitation in millimeters                                          -0.024886
# Pickup Lat                                                            -0.000883
# Pickup Long                                                            0.011036
# Destination Lat                                                       -0.004251
# Destination Long                                                      -0.000900
# Time from Pickup to Arrival                                            0.009744
# No_Of_Orders                                                          -0.024205
# Age                                                                   -0.015514
# Average_Rating                                                        -0.006803
# No_of_Ratings                                                         -0.025768
# time_from_arrival_at_pickup_till_pickup                                0.014216
# time_from_placement_to_pickup                                          0.023336
#
#                                            Pickup - Day of Month  \
# Platform Type                                           0.012770
# Placement - Day of Month                                0.999998
# Placement - Weekday (Mo = 1)                            0.026132
# Confirmation - Day of Month                             1.000000
# Confirmation - Weekday (Mo = 1)                         0.026123
# Arrival at Pickup - Day of Month                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                    0.026123
# Pickup - Day of Month                                   1.000000
# Pickup - Weekday (Mo = 1)                               0.026123
# Arrival at Destination - Day of Month                   1.000000
# Arrival at Destination - Weekday (Mo = 1)               0.026123
# Distance (KM)                                          -0.007587
# Temperature                                             0.011606
# Precipitation in millimeters                           -0.044520
# Pickup Lat                                             -0.004923
# Pickup Long                                            -0.005448
# Destination Lat                                         0.007550
# Destination Long                                        0.002073
# Time from Pickup to Arrival                            -0.014701
# No_Of_Orders                                            0.008099
# Age                                                    -0.000114
# Average_Rating                                          0.012796
# No_of_Ratings                                          -0.001712
# time_from_arrival_at_pickup_till_pickup                 0.003167
# time_from_placement_to_pickup                          -0.011105
#
#                                            Pickup - Weekday (Mo = 1)  \
# Platform Type                                              -0.058005
# Placement - Day of Month                                    0.026122
# Placement - Weekday (Mo = 1)                                0.999952
# Confirmation - Day of Month                                 0.026123
# Confirmation - Weekday (Mo = 1)                             1.000000
# Arrival at Pickup - Day of Month                            0.026123
# Arrival at Pickup - Weekday (Mo = 1)                        1.000000
# Pickup - Day of Month                                       0.026123
# Pickup - Weekday (Mo = 1)                                   1.000000
# Arrival at Destination - Day of Month                       0.026123
# Arrival at Destination - Weekday (Mo = 1)                   1.000000
# Distance (KM)                                               0.003574
# Temperature                                                 0.027712
# Precipitation in millimeters                               -0.024886
# Pickup Lat                                                 -0.000883
# Pickup Long                                                 0.011036
# Destination Lat                                            -0.004251
# Destination Long                                           -0.000900
# Time from Pickup to Arrival                                 0.009744
# No_Of_Orders                                               -0.024205
# Age                                                        -0.015514
# Average_Rating                                             -0.006803
# No_of_Ratings                                              -0.025768
# time_from_arrival_at_pickup_till_pickup                     0.014216
# time_from_placement_to_pickup                               0.023336
#
#                                            Arrival at Destination - Day of Month  \
# Platform Type                                                           0.012770
# Placement - Day of Month                                                0.999998
# Placement - Weekday (Mo = 1)                                            0.026132
# Confirmation - Day of Month                                             1.000000
# Confirmation - Weekday (Mo = 1)                                         0.026123
# Arrival at Pickup - Day of Month                                        1.000000
# Arrival at Pickup - Weekday (Mo = 1)                                    0.026123
# Pickup - Day of Month                                                   1.000000
# Pickup - Weekday (Mo = 1)                                               0.026123
# Arrival at Destination - Day of Month                                   1.000000
# Arrival at Destination - Weekday (Mo = 1)                               0.026123
# Distance (KM)                                                          -0.007587
# Temperature                                                             0.011606
# Precipitation in millimeters                                           -0.044520
# Pickup Lat                                                             -0.004923
# Pickup Long                                                            -0.005448
# Destination Lat                                                         0.007550
# Destination Long                                                        0.002073
# Time from Pickup to Arrival                                            -0.014701
# No_Of_Orders                                                            0.008099
# Age                                                                    -0.000114
# Average_Rating                                                          0.012796
# No_of_Ratings                                                          -0.001712
# time_from_arrival_at_pickup_till_pickup                                 0.003167
# time_from_placement_to_pickup                                          -0.011105
#
#                                                        ...                \
# Platform Type                                          ...
# Placement - Day of Month                               ...
# Placement - Weekday (Mo = 1)                           ...
# Confirmation - Day of Month                            ...
# Confirmation - Weekday (Mo = 1)                        ...
# Arrival at Pickup - Day of Month                       ...
# Arrival at Pickup - Weekday (Mo = 1)                   ...
# Pickup - Day of Month                                  ...
# Pickup - Weekday (Mo = 1)                              ...
# Arrival at Destination - Day of Month                  ...
# Arrival at Destination - Weekday (Mo = 1)              ...
# Distance (KM)                                          ...
# Temperature                                            ...
# Precipitation in millimeters                           ...
# Pickup Lat                                             ...
# Pickup Long                                            ...
# Destination Lat                                        ...
# Destination Long                                       ...
# Time from Pickup to Arrival                            ...
# No_Of_Orders                                           ...
# Age                                                    ...
# Average_Rating                                         ...
# No_of_Ratings                                          ...
# time_from_arrival_at_pickup_till_pickup                ...
# time_from_placement_to_pickup                          ...
#
#                                            Pickup Long  Destination Lat  \
# Platform Type                                 0.021327         0.006319
# Placement - Day of Month                     -0.005453         0.007541
# Placement - Weekday (Mo = 1)                  0.011008        -0.004299
# Confirmation - Day of Month                  -0.005448         0.007550
# Confirmation - Weekday (Mo = 1)               0.011036        -0.004251
# Arrival at Pickup - Day of Month             -0.005448         0.007550
# Arrival at Pickup - Weekday (Mo = 1)          0.011036        -0.004251
# Pickup - Day of Month                        -0.005448         0.007550
# Pickup - Weekday (Mo = 1)                     0.011036        -0.004251
# Arrival at Destination - Day of Month        -0.005448         0.007550
# Arrival at Destination - Weekday (Mo = 1)     0.011036        -0.004251
# Distance (KM)                                 0.178537        -0.079366
# Temperature                                   0.007824         0.009236
# Precipitation in millimeters                 -0.007141        -0.001703
# Pickup Lat                                   -0.147629         0.114975
# Pickup Long                                   1.000000         0.014992
# Destination Lat                               0.014992         1.000000
# Destination Long                              0.082803         0.046767
# Time from Pickup to Arrival                   0.060285        -0.061872
# No_Of_Orders                                  0.011274        -0.001135
# Age                                          -0.001656         0.009552
# Average_Rating                               -0.001885         0.030488
# No_of_Ratings                                 0.002221         0.015015
# time_from_arrival_at_pickup_till_pickup       0.167869        -0.030094
# time_from_placement_to_pickup                 0.163343        -0.019439
#
#                                            Destination Long  \
# Platform Type                                      0.043924
# Placement - Day of Month                           0.002077
# Placement - Weekday (Mo = 1)                      -0.000875
# Confirmation - Day of Month                        0.002073
# Confirmation - Weekday (Mo = 1)                   -0.000900
# Arrival at Pickup - Day of Month                   0.002073
# Arrival at Pickup - Weekday (Mo = 1)              -0.000900
# Pickup - Day of Month                              0.002073
# Pickup - Weekday (Mo = 1)                         -0.000900
# Arrival at Destination - Day of Month              0.002073
# Arrival at Destination - Weekday (Mo = 1)         -0.000900
# Distance (KM)                                      0.135397
# Temperature                                        0.023421
# Precipitation in millimeters                       0.006729
# Pickup Lat                                         0.051399
# Pickup Long                                        0.082803
# Destination Lat                                    0.046767
# Destination Long                                   1.000000
# Time from Pickup to Arrival                        0.070425
# No_Of_Orders                                      -0.013809
# Age                                               -0.018235
# Average_Rating                                     0.002017
# No_of_Ratings                                     -0.002748
# time_from_arrival_at_pickup_till_pickup           -0.015739
# time_from_placement_to_pickup                      0.021374
#
#                                            Time from Pickup to Arrival  \
# Platform Type                                                -0.003827
# Placement - Day of Month                                     -0.014710
# Placement - Weekday (Mo = 1)                                  0.009693
# Confirmation - Day of Month                                  -0.014701
# Confirmation - Weekday (Mo = 1)                               0.009744
# Arrival at Pickup - Day of Month                             -0.014701
# Arrival at Pickup - Weekday (Mo = 1)                          0.009744
# Pickup - Day of Month                                        -0.014701
# Pickup - Weekday (Mo = 1)                                     0.009744
# Arrival at Destination - Day of Month                        -0.014701
# Arrival at Destination - Weekday (Mo = 1)                     0.009744
# Distance (KM)                                                 0.580608
# Temperature                                                   0.005772
# Precipitation in millimeters                                  0.005495
# Pickup Lat                                                   -0.053823
# Pickup Long                                                   0.060285
# Destination Lat                                              -0.061872
# Destination Long                                              0.070425
# Time from Pickup to Arrival                                   1.000000
# No_Of_Orders                                                 -0.041608
# Age                                                          -0.007969
# Average_Rating                                               -0.042559
# No_of_Ratings                                                 0.005609
# time_from_arrival_at_pickup_till_pickup                      -0.079637
# time_from_placement_to_pickup                                 0.067928
#
#                                            No_Of_Orders       Age  \
# Platform Type                                  0.024060 -0.074029
# Placement - Day of Month                       0.008096 -0.000107
# Placement - Weekday (Mo = 1)                  -0.024226 -0.015475
# Confirmation - Day of Month                    0.008099 -0.000114
# Confirmation - Weekday (Mo = 1)               -0.024205 -0.015514
# Arrival at Pickup - Day of Month               0.008099 -0.000114
# Arrival at Pickup - Weekday (Mo = 1)          -0.024205 -0.015514
# Pickup - Day of Month                          0.008099 -0.000114
# Pickup - Weekday (Mo = 1)                     -0.024205 -0.015514
# Arrival at Destination - Day of Month          0.008099 -0.000114
# Arrival at Destination - Weekday (Mo = 1)     -0.024205 -0.015514
# Distance (KM)                                  0.037186  0.036239
# Temperature                                    0.030102 -0.037470
# Precipitation in millimeters                   0.012714  0.012079
# Pickup Lat                                    -0.018190  0.002481
# Pickup Long                                    0.011274 -0.001656
# Destination Lat                               -0.001135  0.009552
# Destination Long                              -0.013809 -0.018235
# Time from Pickup to Arrival                   -0.041608 -0.007969
# No_Of_Orders                                   1.000000  0.669036
# Age                                            0.669036  1.000000
# Average_Rating                                 0.051375 -0.014348
# No_of_Ratings                                  0.857918  0.651090
# time_from_arrival_at_pickup_till_pickup        0.085999  0.057463
# time_from_placement_to_pickup                 -0.006471  0.005636
#
#                                            Average_Rating  No_of_Ratings  \
# Platform Type                                   -0.014664      -0.031886
# Placement - Day of Month                         0.012790      -0.001709
# Placement - Weekday (Mo = 1)                    -0.006834      -0.025747
# Confirmation - Day of Month                      0.012796      -0.001712
# Confirmation - Weekday (Mo = 1)                 -0.006803      -0.025768
# Arrival at Pickup - Day of Month                 0.012796      -0.001712
# Arrival at Pickup - Weekday (Mo = 1)            -0.006803      -0.025768
# Pickup - Day of Month                            0.012796      -0.001712
# Pickup - Weekday (Mo = 1)                       -0.006803      -0.025768
# Arrival at Destination - Day of Month            0.012796      -0.001712
# Arrival at Destination - Weekday (Mo = 1)       -0.006803      -0.025768
# Distance (KM)                                   -0.008200       0.051806
# Temperature                                     -0.024769      -0.007461
# Precipitation in millimeters                    -0.000432       0.014191
# Pickup Lat                                       0.043610       0.019458
# Pickup Long                                     -0.001885       0.002221
# Destination Lat                                  0.030488       0.015015
# Destination Long                                 0.002017      -0.002748
# Time from Pickup to Arrival                     -0.042559       0.005609
# No_Of_Orders                                     0.051375       0.857918
# Age                                             -0.014348       0.651090
# Average_Rating                                   1.000000       0.073856
# No_of_Ratings                                    0.073856       1.000000
# time_from_arrival_at_pickup_till_pickup         -0.040121       0.025639
# time_from_placement_to_pickup                   -0.052898      -0.012328
#
#                                            time_from_arrival_at_pickup_till_pickup  \
# Platform Type                                                             0.053344
# Placement - Day of Month                                                  0.003164
# Placement - Weekday (Mo = 1)                                              0.014198
# Confirmation - Day of Month                                               0.003167
# Confirmation - Weekday (Mo = 1)                                           0.014216
# Arrival at Pickup - Day of Month                                          0.003167
# Arrival at Pickup - Weekday (Mo = 1)                                      0.014216
# Pickup - Day of Month                                                     0.003167
# Pickup - Weekday (Mo = 1)                                                 0.014216
# Arrival at Destination - Day of Month                                     0.003167
# Arrival at Destination - Weekday (Mo = 1)                                 0.014216
# Distance (KM)                                                             0.103044
# Temperature                                                               0.039129
# Precipitation in millimeters                                             -0.010755
# Pickup Lat                                                               -0.121053
# Pickup Long                                                               0.167869
# Destination Lat                                                          -0.030094
# Destination Long                                                         -0.015739
# Time from Pickup to Arrival                                              -0.079637
# No_Of_Orders                                                              0.085999
# Age                                                                       0.057463
# Average_Rating                                                           -0.040121
# No_of_Ratings                                                             0.025639
# time_from_arrival_at_pickup_till_pickup                                   1.000000
# time_from_placement_to_pickup                                             0.485941
#
#                                            time_from_placement_to_pickup
# Platform Type                                                   0.020411
# Placement - Day of Month                                       -0.011117
# Placement - Weekday (Mo = 1)                                    0.023269
# Confirmation - Day of Month                                    -0.011105
# Confirmation - Weekday (Mo = 1)                                 0.023336
# Arrival at Pickup - Day of Month                               -0.011105
# Arrival at Pickup - Weekday (Mo = 1)                            0.023336
# Pickup - Day of Month                                          -0.011105
# Pickup - Weekday (Mo = 1)                                       0.023336
# Arrival at Destination - Day of Month                          -0.011105
# Arrival at Destination - Weekday (Mo = 1)                       0.023336
# Distance (KM)                                                   0.083299
# Temperature                                                     0.011775
# Precipitation in millimeters                                    0.012418
# Pickup Lat                                                     -0.109842
# Pickup Long                                                     0.163343
# Destination Lat                                                -0.019439
# Destination Long                                                0.021374
# Time from Pickup to Arrival                                     0.067928
# No_Of_Orders                                                   -0.006471
# Age                                                             0.005636
# Average_Rating                                                 -0.052898
# No_of_Ratings                                                  -0.012328
# time_from_arrival_at_pickup_till_pickup                         0.485941
# time_from_placement_to_pickup                                   1.000000
#
# [25 rows x 25 columns]

# %%
sendy_train['Platform Type']= sendy_train['Platform Type'].astype(object)

# %%
cols= ['Placement - Day of Month', 'Placement - Weekday (Mo = 1)','Confirmation - Day of Month','Confirmation - Weekday (Mo = 1)', 
       'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Weekday (Mo = 1)','Pickup - Day of Month',
       'Pickup - Weekday (Mo = 1)','Arrival at Destination - Day of Month', 'Arrival at Destination - Weekday (Mo = 1)']
for column in cols:
    sendy_train[column]=sendy_train.astype(object)
    dummies= pd.get_dummies(sendy_train[column])

# %%
sendy_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21201 entries, 0 to 21200
# Data columns (total 35 columns):
# Order No                                     21201 non-null object
# User Id                                      21201 non-null object
# Vehicle Type                                 21201 non-null object
# Platform Type                                21201 non-null object
# Personal or Business                         21201 non-null object
# Placement - Day of Month                     21201 non-null object
# Placement - Weekday (Mo = 1)                 21201 non-null object
# Confirmation - Day of Month                  21201 non-null object
# Confirmation - Weekday (Mo = 1)              21201 non-null object
# Arrival at Pickup - Day of Month             21201 non-null object
# Arrival at Pickup - Weekday (Mo = 1)         21201 non-null object
# Pickup - Day of Month                        21201 non-null object
# Pickup - Weekday (Mo = 1)                    21201 non-null object
# Arrival at Destination - Day of Month        21201 non-null object
# Arrival at Destination - Weekday (Mo = 1)    21201 non-null object
# Distance (KM)                                21201 non-null int64
# Temperature                                  21201 non-null float64
# Precipitation in millimeters                 21201 non-null float64
# Pickup Lat                                   21201 non-null float64
# Pickup Long                                  21201 non-null float64
# Destination Lat                              21201 non-null float64
# Destination Long                             21201 non-null float64
# Rider Id                                     21201 non-null object
# Time from Pickup to Arrival                  21201 non-null int64
# No_Of_Orders                                 21201 non-null int64
# Age                                          21201 non-null int64
# Average_Rating                               21201 non-null float64
# No_of_Ratings                                21201 non-null int64
# pickup_time                                  21201 non-null datetime64[ns]
# arrival_at_pickup_time                       21201 non-null datetime64[ns]
# placement_time                               21201 non-null datetime64[ns]
# time_from_arrival_at_pickup_till_pickup      21201 non-null float64
# time_from_placement_to_pickup                21201 non-null float64
# confirmation_time                            21201 non-null datetime64[ns]
# arrival_at_destination_time                  21201 non-null datetime64[ns]
# dtypes: datetime64[ns](5), float64(9), int64(5), object(16)
# memory usage: 5.8+ MB

# %%
from sklearn import preprocessing
from sklearn import linear_model
import sklearn.metrics as skl

# %%
sendy_train['time_from_pickup_arrival']= sendy_train['Time from Pickup to Arrival']

# %%
sendy_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7068 entries, 0 to 7067
# Data columns (total 31 columns):
# Order No                                   7068 non-null object
# User Id                                    7068 non-null object
# Vehicle Type                               7068 non-null object
# Platform Type                              7068 non-null int64
# Personal or Business                       7068 non-null object
# Placement - Day of Month                   7068 non-null int64
# Placement - Weekday (Mo = 1)               7068 non-null int64
# Confirmation - Day of Month                7068 non-null int64
# Confirmation - Weekday (Mo = 1)            7068 non-null int64
# Arrival at Pickup - Day of Month           7068 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)       7068 non-null int64
# Pickup - Day of Month                      7068 non-null int64
# Pickup - Weekday (Mo = 1)                  7068 non-null int64
# Distance (KM)                              7068 non-null int64
# Temperature                                7068 non-null float64
# Precipitation in millimeters               7068 non-null float64
# Pickup Lat                                 7068 non-null float64
# Pickup Long                                7068 non-null float64
# Destination Lat                            7068 non-null float64
# Destination Long                           7068 non-null float64
# Rider Id                                   7068 non-null object
# No_Of_Orders                               7068 non-null int64
# Age                                        7068 non-null int64
# Average_Rating                             7068 non-null float64
# No_of_Ratings                              7068 non-null int64
# pickup_time                                7068 non-null datetime64[ns]
# arrival_at_pickup_time                     7068 non-null datetime64[ns]
# placement_time                             7068 non-null datetime64[ns]
# time_from_arrival_at_pickup_till_pickup    7068 non-null float64
# time_from_placement_to_pickup              7068 non-null float64
# confirmation_time                          7068 non-null datetime64[ns]
# dtypes: datetime64[ns](4), float64(9), int64(13), object(5)
# memory usage: 1.7+ MB

# %%
xtra=sendy_train[['Distance (KM)','Temperature','Precipitation in millimeters','Pickup Lat','Pickup Long','Destination Lat','Destination Long','time_from_arrival_at_pickup_till_pickup','time_from_placement_to_pickup','No_Of_Orders','Average_Rating','No_of_Ratings','Age']]
xte=sendy_test[['Distance (KM)','Temperature','Precipitation in millimeters','Pickup Lat','Pickup Long','Destination Lat','Destination Long','time_from_arrival_at_pickup_till_pickup','time_from_placement_to_pickup','No_Of_Orders','Average_Rating','No_of_Ratings','Age']]

# %%
y=sendy_train['Time from Pickup to Arrival']

# %%
xtra= xtra.apply(pd.to_numeric, errors='coerce')
xte= xte.apply(pd.to_numeric, errors='coerce')
y= y.apply(pd.to_numeric, errors='coerce')
xtra.fillna(0, inplace=True)
xte.fillna(0, inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xtra, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn import metrics as sklm
import math

# %%
def print_metrics(y_true, y_predicted, n_parameters):
    ## First compute R^2 and the adjusted R^2
    r2 = sklm.r2_score(y_true, y_predicted)
    r2_adj = r2 - (n_parameters - 1)/(y_true.shape[0] - n_parameters) * (1 - r2)
    
    ## Print the usual metrics and the R^2 values
    print('Mean Square Error      = ' + str(sklm.mean_squared_error(y_true, y_predicted)))
    print('Root Mean Square Error = ' + str(math.sqrt(sklm.mean_squared_error(y_true, y_predicted))))
    print('Mean Absolute Error    = ' + str(sklm.mean_absolute_error(y_true, y_predicted)))
    print('Median Absolute Error  = ' + str(sklm.median_absolute_error(y_true, y_predicted)))
    print('R^2                    = ' + str(r2))
    print('Adjusted R^2           = ' + str(r2_adj))
   
y_score = lm.predict(x_test) 
print_metrics(y_test, y_score, 9)
# Out:
# Mean Square Error      = 589411.2247480145
# Root Mean Square Error = 767.7312190786658
# Mean Absolute Error    = 547.8887933600982
# Median Absolute Error  = 403.7352583771135
# R^2                    = 0.37914389577736507
# Adjusted R^2           = 0.3779702547485888

# %%
from catboost import CatBoostRegressor

# %%
cat_reg = CatBoostRegressor(iterations=1000,
                          learning_rate=1,
                          depth=4)

# %%
cat_reg.fit(x_train,y_train)
# Out:
# 0:	learn: 852.5133878	total: 103ms	remaining: 1m 43s
# 1:	learn: 813.5143768	total: 202ms	remaining: 1m 40s
# 2:	learn: 802.6515937	total: 272ms	remaining: 1m 30s
# 3:	learn: 791.0632815	total: 358ms	remaining: 1m 29s
# 4:	learn: 786.1250068	total: 419ms	remaining: 1m 23s
# 5:	learn: 779.7985272	total: 475ms	remaining: 1m 18s
# 6:	learn: 773.5668884	total: 526ms	remaining: 1m 14s
# 7:	learn: 772.1408231	total: 619ms	remaining: 1m 16s
# 8:	learn: 768.8374800	total: 678ms	remaining: 1m 14s
# 9:	learn: 764.0579638	total: 731ms	remaining: 1m 12s
# 10:	learn: 762.1290074	total: 784ms	remaining: 1m 10s
# 11:	learn: 760.1255152	total: 876ms	remaining: 1m 12s
# 12:	learn: 758.2902755	total: 960ms	remaining: 1m 12s
# 13:	learn: 756.9461517	total: 1.01s	remaining: 1m 11s
# 14:	learn: 754.4308531	total: 1.06s	remaining: 1m 9s
# 15:	learn: 753.5577398	total: 1.15s	remaining: 1m 10s
# 16:	learn: 752.6007418	total: 1.19s	remaining: 1m 8s
# 17:	learn: 752.3376773	total: 1.23s	remaining: 1m 7s
# 18:	learn: 751.4789465	total: 1.28s	remaining: 1m 5s
# 19:	learn: 749.7683664	total: 1.32s	remaining: 1m 4s
# 20:	learn: 747.7118824	total: 1.4s	remaining: 1m 5s
# 21:	learn: 746.6100049	total: 1.44s	remaining: 1m 4s
# 22:	learn: 745.5684403	total: 1.48s	remaining: 1m 2s
# 23:	learn: 744.9847970	total: 1.52s	remaining: 1m 1s
# 24:	learn: 744.4571078	total: 1.56s	remaining: 1m 1s
# 25:	learn: 743.1212897	total: 1.62s	remaining: 1m
# 26:	learn: 743.0090514	total: 1.69s	remaining: 1m
# 27:	learn: 742.0384233	total: 1.73s	remaining: 59.9s
# 28:	learn: 741.2045182	total: 1.77s	remaining: 59.2s
# 975:	learn: 641.9154355	total: 1m 2s	remaining: 1.54s
# 976:	learn: 641.7138677	total: 1m 2s	remaining: 1.48s
# 977:	learn: 641.7072055	total: 1m 2s	remaining: 1.41s
# 978:	learn: 641.5573023	total: 1m 2s	remaining: 1.35s
# 979:	learn: 641.5508911	total: 1m 2s	remaining: 1.28s
# 980:	learn: 641.5418079	total: 1m 3s	remaining: 1.22s
# 981:	learn: 641.5323922	total: 1m 3s	remaining: 1.16s
# 982:	learn: 641.4568561	total: 1m 3s	remaining: 1.09s
# 983:	learn: 641.4558658	total: 1m 3s	remaining: 1.03s
# 984:	learn: 641.3994809	total: 1m 3s	remaining: 963ms
# 985:	learn: 641.3962772	total: 1m 3s	remaining: 899ms
# 986:	learn: 641.3841544	total: 1m 3s	remaining: 834ms
# 987:	learn: 641.3763980	total: 1m 3s	remaining: 770ms
# 988:	learn: 641.2968342	total: 1m 3s	remaining: 705ms
# 989:	learn: 641.2849173	total: 1m 3s	remaining: 641ms
# 990:	learn: 641.2705871	total: 1m 3s	remaining: 577ms
# 991:	learn: 641.2150936	total: 1m 3s	remaining: 513ms
# 992:	learn: 641.2052541	total: 1m 3s	remaining: 449ms
# 993:	learn: 641.1813760	total: 1m 3s	remaining: 385ms
# 994:	learn: 641.1629228	total: 1m 3s	remaining: 321ms
# 995:	learn: 641.1625872	total: 1m 3s	remaining: 257ms
# 996:	learn: 641.1261931	total: 1m 3s	remaining: 192ms
# 997:	learn: 641.1253351	total: 1m 3s	remaining: 128ms
# 998:	learn: 640.9954482	total: 1m 4s	remaining: 64.1ms
# 999:	learn: 640.9926333	total: 1m 4s	remaining: 0us

# %%
preds = cat_reg.predict(xte)

# %%
cat_reg.score(x_train,y_train)

# %%
sendy_newtest= pd.read_csv('test.csv')

# %%
sendy_newtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7068 entries, 0 to 7067
# Data columns (total 25 columns):
# Order No                                7068 non-null object
# User Id                                 7068 non-null object
# Vehicle Type                            7068 non-null object
# Platform Type                           7068 non-null int64
# Personal or Business                    7068 non-null object
# Placement - Day of Month                7068 non-null int64
# Placement - Weekday (Mo = 1)            7068 non-null int64
# Placement - Time                        7068 non-null object
# Confirmation - Day of Month             7068 non-null int64
# Confirmation - Weekday (Mo = 1)         7068 non-null int64
# Confirmation - Time                     7068 non-null object
# Arrival at Pickup - Day of Month        7068 non-null int64
# Arrival at Pickup - Weekday (Mo = 1)    7068 non-null int64
# Arrival at Pickup - Time                7068 non-null object
# Pickup - Day of Month                   7068 non-null int64
# Pickup - Weekday (Mo = 1)               7068 non-null int64
# Pickup - Time                           7068 non-null object
# Distance (KM)                           7068 non-null int64
# Temperature                             5631 non-null float64
# Precipitation in millimeters            199 non-null float64
# Pickup Lat                              7068 non-null float64
# Pickup Long                             7068 non-null float64
# Destination Lat                         7068 non-null float64
# Destination Long                        7068 non-null float64
# Rider Id                                7068 non-null object
# dtypes: float64(6), int64(10), object(9)
# memory usage: 1.3+ MB

# %%
preds = preds.astype(np.int)
submission = pd.DataFrame({'Time from Pickup to Arrival':preds,'Order No':sendy_newtest['Order No']})

# %%
submission.to_csv('sendy_result.csv',index=False)
